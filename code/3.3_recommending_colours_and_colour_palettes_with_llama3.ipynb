# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Capstone Project: Harmony
# ## 3.3 Recommending Colours and Colour Palettes with Llama3
# > Authors: Eugene Matthew Cheong
# ---

# %% [markdown]
# ## Table of Contents ##
#
# #### 1. Web Scraping
#
# - [1.1 Scraping Lian Seng Hin Website](1.1_web_scraping_liansenghin.ipynb)
# - [1.2 Scraping Hafary Website](1.2_web_scraping_hafary.ipynb)
# - [1.3 Scraping Lamitak Website](1.3_web_scraping_lamitak.ipynb)
# - [1.4 Scraping Nippon Website](1.4_web_scraping_nippon.ipynb)
# - [1.5 Consolidate All Product Database](1.5_consolidate_product_database.ipynb)
#
# #### 2. Preprocessing
#
# - [2.1 Processing Canva Palettes](2.1_processing_canva_palette.ipynb)
#
# #### 3. Modelling
#
# - [3.1 Matching Input Photo to Products](3.1_matching_input_photo_to_products.ipynb)
# - [3.2 Recommending Canva Palette to Products](3.2_recommending_canva_palette_to_product.ipynb)
# - [3.3 Recommending Colours and Colour Palettes with Llama3](3.3_recommending_colours_and_colour_palettes_with_llama3.ipynb)

# %% [markdown]
# ---

# %% [markdown]
# # Import Modules

# %%
import re
import os
import pandas as pd
import numpy as np


import ollama

# %%
file_path = '../datasets/color_palette_df.csv'
canva_palettes_df = pd.read_csv(file_path)

# %% [markdown]
# ### Formatting the colour palette dataframe into a string for the LLM to reference

# %%
# Create a formatted string for each row to display palette name and the four colors
formatted_strings = ["'Palette: {} - Colors: {}, {}, {}, {}'".format(row['Name'], row['Color 1'], row['Color 2'], row['Color 3'], row['Color 4']) for index, row in canva_palettes_df.iterrows()]

# Join all formatted strings into a single string with each palette on a new line
color_palette_output = "Only recommend colour palettes from this list:\n"

color_palette_list_string = "\n".join(formatted_strings)

color_palette_output += color_palette_list_string

# %%
print(color_palette_output)
# Out:
# Only recommend colour palettes from this list:
# 'Palette: Rosettes and Cream - Colors: #EF7C8E, #FAE8E0, #B6E2D3, #D8A7B1'
# 'Palette: Rosy Flamingo - Colors: #E8B4B8, #EED6D3, #A49393, #67595E'
# 'Palette: Summer Splash - Colors: #05445E, #189AB4, #75E6DA, #D4F1F4'
# 'Palette: Pastel Dreams - Colors: #FBE7C6, #B4F8C8, #A0E7E5, #FFAEBC'
# 'Palette: Room for Comfort - Colors: #E7D2CC, #B9B7BD, #868B8E, #EEEDE7'
# 'Palette: The Deep Blue - Colors: #050A30, #000C66, #0000FF, #7EC8E3'
# 'Palette: Emerald Entrance - Colors: #B68D40, #F4EBD0, #122620, #D6AD60'
# 'Palette: Mermaid Lagoon - Colors: #145DA0, #0C2D48, #2E8BC0, #B1D4E0'
# 'Palette: Retro Punch - Colors: #2FF3E0, #F8D210, #FA26A0, #F51720'
# 'Palette: Healthy Leaves - Colors: #3D550C, #81B622, #ECF87F, #59981A'
# 'Palette: Right on Time - Colors: #F6EEE0, #E4B7A0, #A45C40, #C38370'
# 'Palette: Window Tide - Colors: #41729F, #5885AF, #274472, #C3E0E5'
# 'Palette: Padlocked Doors - Colors: #B99095, #FCB5AC, #B5E5CF, #3D5B59'
# 'Palette: Salmon Sushi - Colors: #E7F2F8, #74BDCB, #FFA384, #EFE7BC'
# 'Palette: Thwarted Summer Shower - Colors: #BCECE0, #36EEE0, #F652A0, #4C5270'
# 'Palette: Scooping Ice Cream - Colors: #E4D4C8, #D0B49F, #A47551, #523A28'
# 'Palette: Sweet Cotton Sugar - Colors: #EFEBE0, #FB8DA0, #FB6B90, #FB4570'
# 'Palette: Easter Egg Nest - Colors: #BBE7FE, #D3B5E5, #FFD4DB, #EFF1DB'
# 'Palette: Bright Lights - Colors: #68BBE3, #0E86D4, #055C9D, #003060'
# 'Palette: Afternoon Sinkers - Colors: #FFC2C7, #B6E5D8, #FBE5C8, #8FDDE7'
# 'Palette: Cheeky Marguerita - Colors: #0A7029, #FEDE00, #C8DF52, #DBE8D8'
# 'Palette: Water Foam - Colors: #DDFFE7, #98D7C2, #167D7F, #29A0B1'
# 'Palette: Pastel Blonde - Colors: #FFF4BD, #F4B9B8, #85D2D0, #887BB0'
# 'Palette: Rocks and Barefoot - Colors: #EDE7DC, #DCD2CC, #CCAFA5, #BDC3CB'
# 'Palette: Everything Nice - Colors: #603F8B, #B4FEE7, #A16AE8, #FD49A0'
# 'Palette: Clusters of Beauty - Colors: #D48C70, #F4B9B8, #EBBBB0, #E98980'
# 'Palette: Green Blaze - Colors: #76B947, #B1D8B7, #2F5233, #94C973'
# 'Palette: Under the Ferns - Colors: #116530, #21B6A8, #A3EBB1, #18A558'
# 'Palette: Rosy Afters - Colors: #FFC5D0, #F7D6D0, #FB6090, #821D30'
# 'Palette: Icy Gradient - Colors: #EEB5EB, #C26DBC, #C8F4F9, #3CACAE'
# 'Palette: Soft in Hue - Colors: #F8C0C8, #EFE7D3, #D3BBDD, #ECE3F0'
# 'Palette: San Francisco Clouded - Colors: #4297A0, #F4EAE6, #E57F84, #2F5061'
# 'Palette: Warm Sunset - Colors: #FD7F20, #FC2E20, #FDB750, #010100'
# 'Palette: Facing Forward - Colors: #E5DDC8, #01949A, #004369, #DB1F48'
# 'Palette: Birth Spring - Colors: #BCA88E, #E3E8E9, #9DA993, #E4B4B4'
# 'Palette: Cupcake Delight - Colors: #EBE0D0, #EC9EC0, #FF0080, #A91B60'
# 'Palette: Pasture of Dreams - Colors: #D3B1C2, #C197D2, #211522, #613659'
# 'Palette: Luscious Lemonade - Colors: #F8EA8C, #A4E8E0, #4CD7D0, #E1C340'
# 'Palette: Forever Fields - Colors: #B7AC44, #DF362D, #FF8300, #FF4500'
# 'Palette: Foil-covered Sneakers - Colors: #90ADC6, #E9EAEC, #FAD02C, #333652'
# 'Palette: Petal Party - Colors: #F2C5E0, #D43790, #EC8FD0, #870A30'
# 'Palette: Green Lemons - Colors: #013A20, #478C5C, #BACC81, #CDD193'
# 'Palette: Speckled Eggs - Colors: #BFD7ED, #60A3D9, #0074B7, #003B73'
# 'Palette: Soft Focus Forest - Colors: #175873, #2B7C85, #87ACA3, #0C1446'
# 'Palette: Sea of Serenity - Colors: #04ECF0, #04D4F0, #6AF2F0, #059DC0'
# 'Palette: Rose Petals - Colors: #3B0404, #DEB3AD, #DE847B, #B95C50'
# 'Palette: Here at Home - Colors: #647C90, #E2DED0, #4E4F50, #746C70'
# 'Palette: Timeless Beauty - Colors: #DACAC4, #F7C9B6, #DBC39A, #DAE7DD'
# 'Palette: Skater Girl - Colors: #E56997, #BD97CB, #FBC740, #66D2D6'
# 'Palette: Strawberry Froth - Colors: #FABEC0, #F85C70, #F37970, #E43D40'
# 'Palette: Royal Elegant - Colors: #FBEDE0, #FDD1D2, #D4BBDD, #D0AB99'
# 'Palette: Secret Passageway - Colors: #32CD30, #2C5E1A, #1A4314, #B2D2A4'
# 'Palette: Trees in Bloom - Colors: #F9CCD3, #AA1945, #F1CED4, #391306'
# 'Palette: Bubblegum Sweetness - Colors: #0C6170, #37BEB0, #A4E5E0, #DBF5F0'
# 'Palette: Cool Cream Strawberry - Colors: #E7625F, #C85250, #F7BEC0, #E9EAE0'
# 'Palette: Painting with Pastels - Colors: #F2E6D6, #A0E0E4, #FCC0C5, #F582A8'
# 'Palette: Toasted Peach - Colors: #FBAA60, #FBC490, #F67B50, #A82810'
# 'Palette: Shopping Spree - Colors: #F9D030, #F62AA0, #B8EE30, #26DFD0'
# 'Palette: Melted Ice Cream - Colors: #5BB0BA, #C15B78, #EBF5F7, #F6C8CC'
# 'Palette: Pastel Meltaways - Colors: #FEE7E6, #ECFDF1, #F9EAC2, #FFD898'
# 'Palette: Gingerbread Ice Cream - Colors: #6F5B3E, #F9F6F0, #C4AE78, #171515'
# 'Palette: Ripe Harvest - Colors: #FF5C4D, #FF9636, #FFCD58, #DAD870'
# 'Palette: Backdoor Casual - Colors: #E98973, #E7D4C0, #88B2CC, #658EA9'
# 'Palette: Colored Coolers - Colors: #F6A21E, #E55B13, #104210, #7A871E'
# 'Palette: Mellow Barnyard - Colors: #E6C2BF, #F8EFE4, #FAD02C, #282120'
# 'Palette: Red Beanie Practise - Colors: #BA0F30, #2F2440, #C6B79B, #FF2511'
# 'Palette: Mountain Haze - Colors: #C3CEDA, #738FA7, #0C4160, #071330'
# 'Palette: Sugar and Spice - Colors: #B7C8C2, #ECA4B1, #E9DAC4, #CFB2B0'
# 'Palette: Modern Pastel Life - Colors: #F0E1DE, #F7C9B6, #549BAD, #83BDC0'
# 'Palette: Berry Blues - Colors: #05E0E9, #FF2768, #CFEED1, #4E1A3D'
# 'Palette: Fresh for Picking - Colors: #F7D6C0, #F4B9B8, #96AD90, #3A4A3D'
# 'Palette: Sun Ready - Colors: #FC8BC0, #FA53A0, #25C0C0, #F3BC50'
# 'Palette: Fresh Grapefruit - Colors: #ACEEF3, #FF7077, #FFE9E4, #FFB067'
# 'Palette: In the Blue - Colors: #C4DBE0, #2EB5E0, #00A8A8, #0C6980'
# 'Palette: Ice Infinity - Colors: #D9E4EC, #B7CFDC, #6AABD2, #385E72'
# 'Palette: Sunlit Eggplant - Colors: #EFD3B5, #5F093D, #B21368, #D67BA8'
# 'Palette: Wall Greens - Colors: #778A35, #D1E2C4, #EBEBE8, #31352E'
# 'Palette: Ramp It Up - Colors: #F3E1C0, #EBAAB0, #275070, #955670'
# 'Palette: Lake View - Colors: #54627B, #ECD5BB, #FFFFFF, #710117'
# 'Palette: Watermelon and Stripes - Colors: #D2FBA4, #F1C0B9, #88CA5E, #1D741B'
# 'Palette: Apple Shine - Colors: #FF8370, #00B1B0, #FEC84D, #E42256'
# 'Palette: Middle Eastern Empire - Colors: #922C40, #DC9750, #F3EAC0, #1E2640'
# 'Palette: Towering Over - Colors: #0000A3, #0067B3, #40B0DF, #FFD53D'
# 'Palette: Bubbly Banana - Colors: #15B5B0, #F9BDC0, #FBE698, #6DECE0'
# 'Palette: Coffee Run - Colors: #39918C, #D0B49F, #AB6B51, #2F435A'
# 'Palette: Pomegranate Crush - Colors: #DC4731, #FFF3D9, #B8390E, #3B0918'
# 'Palette: Diaphanous Jellyfish - Colors: #B4F5F0, #2CEEF0, #0476D0, #041F60'
# 'Palette: Purple Fabric - Colors: #BEAFC2, #695E93, #8155BA, #281C2D'
# 'Palette: Muted Overview - Colors: #535E4B, #C1C2AD, #B5A4A3, #E9E6E2'
# 'Palette: Dark Road Curve - Colors: #0A0708, #444444, #747474, #B1B1B1'
# 'Palette: Crack of Dawn - Colors: #001F3D, #045174, #D89C60, #E87A00'
# 'Palette: Stacked Cupcake Cups - Colors: #EAE6F0, #F7CAC9, #D68FB0, #BF3880'
# 'Palette: Soft Slippers - Colors: #B4AAA9, #FFF0DF, #F8FAFD, #F0C9B3'
# 'Palette: Northern Lights - Colors: #1A5653, #107869, #5CD85A, #08313A'
# 'Palette: Sweet and Nice - Colors: #C59894, #F0D1BF, #F7C9B6, #877785'
# 'Palette: Sweeter Love - Colors: #A58CB3, #838BC2, #EAE7FA, #D9A1A0'
# 'Palette: Sugar Rush - Colors: #FFB067, #FFED86, #A2DCE7, #F8CCDC'
# 'Palette: Blushing Landscape - Colors: #FFA384, #E88D72, #543855, #FF8882'
# 'Palette: Candy Hearts - Colors: #FEC8A7, #FCECA5, #B5EECB, #CBC7FC'
# 'Palette: One Fine Day - Colors: #533440, #A47786, #E4D4C8, #9DB6CC'
# 'Palette: Northern Lights 2 - Colors: #1DC690, #278AB0, #1C4670, #EAEAE0'
# 'Palette: Smiling Roses - Colors: #E2808A, #F1CCD7, #2E765E, #638C80'
# 'Palette: Letters of Affection - Colors: #CB857C, #F6CBB7, #FAF7F4, #9C2D41'
# 'Palette: Meringues and Tea - Colors: #BBA78C, #EFEAE4, #F4C6D4, #F3DBB2'
# 'Palette: Shopaholic Babe - Colors: #FFC5D0, #FFFF00, #22CAE0, #F52EC0'
# 'Palette: Arts and Crafts - Colors: #D773A2, #07BB9C, #FFD743, #A06AB4'
# 'Palette: Way up North - Colors: #E8EEF1, #43B0F1, #057DCD, #1E3D58'
# 'Palette: Colorful Powder Cracks - Colors: #54086B, #FF0BAC, #00BEC5, #050833'
# 'Palette: Pulp Slices - Colors: #0A4158, #4B8378, #FF9636, #E4D7D0'
# 'Palette: Steel Cutlery - Colors: #99B0B0, #B5B2B0, #FCFAF0, #8A9EA0'
# 'Palette: Flowers Like Eyes - Colors: #C55FFC, #EFDCF9, #323E42, #7954A1'
# 'Palette: Bold Geometry - Colors: #0D698B, #F2F1E8, #050533, #E34234'
# 'Palette: Wild Orchid - Colors: #005437, #DEBAD6, #340744, #741AAC'
# 'Palette: Up Shore - Colors: #DEE2EC, #8C756A, #1AC8DB, #0292B7'
# 'Palette: Sunset Waters - Colors: #F6D4D2, #A16AE8, #4120A9, #A1A9FE'
# 'Palette: In a Trance - Colors: #FADCDC, #4D4C60, #D691A0, #C45F90'
# 'Palette: Plum and Gold - Colors: #D6C099, #D6CEC0, #8E8A92, #AE8781'
# 'Palette: Tea and Romance - Colors: #F9F1F0, #663635, #E1999F, #DEB3AD'
# 'Palette: Fresh Blankets - Colors: #774A62, #FBD2C9, #313E61, #81ABBC'
# 'Palette: Spike of Mint - Colors: #7CF3A0, #B4F8C8, #FF75D8, #FF45B5'
# 'Palette: Velvet Petals - Colors: #0E050F, #170B3B, #341948, #9388A2'
# 'Palette: Cool Berry Scoop - Colors: #FFA3B8, #F7D6D0, #FC3C80, #821D30'
# 'Palette: Pale Blossom - Colors: #98042D, #BF4C41, #FCC0C5, #E1E2E7'
# 'Palette: Always Look Up - Colors: #EAFBFF, #77DDF9, #FFA0A3, #7F8FA3'
# 'Palette: Heart of Coral - Colors: #F0CCB0, #B97D60, #F0A160, #F54D3D'
# 'Palette: Spread Your Wings - Colors: #31B4F2, #0000FF, #025492, #F8CF40'
# 'Palette: Floating Seaside - Colors: #E4F4F3, #A1DBF1, #71D5E4, #00B6BC'
# 'Palette: Rainbow Doughnuts - Colors: #FF5765, #FFDB15, #8A6FDF, #A8E10C'
# 'Palette: Morning Espresso - Colors: #5C4E4E, #988686, #D1D0D0, #000000'
# 'Palette: Power Up - Colors: #E9DDD4, #000000, #E9DDD4, #900020'
# 'Palette: Metal and Glass - Colors: #D01110, #0A0A00, #A8BBB0, #EBE8E0'
# 'Palette: Raspberry Cream - Colors: #AE388B, #5DF15D, #E983D8, #F9B4F6'
# 'Palette: Black Bird - Colors: #140005, #464033, #7E7C73, #BBC4C2'
# 'Palette: Freshly Picked Oranges - Colors: #ADA7A7, #D3D3CB, #D37506, #9F2B00'
# 'Palette: Chocolate Chip Delight - Colors: #4F0000, #D9CED6, #303437, #AE8B70'
# 'Palette: Robin Egg Frosting - Colors: #16796F, #7CB7AF, #CADEDF, #9CA89E'
# 'Palette: Lava Sky - Colors: #E95670, #B34270, #713770, #432F70'
# 'Palette: Piece of Cake - Colors: #F7E3D9, #F9C7E4, #C6D8D5, #FEEDCF'
# 'Palette: Rabbit in Grass - Colors: #65463E, #AAD6A0, #DCBAA9, #D2E5D0'
# 'Palette: Midnight Waters - Colors: #BDC6D9, #52688F, #E3E7F1, #7391C8'
# 'Palette: Trees During Fall - Colors: #DBA40E, #4B5A20, #787D12, #7E6E13'
# 'Palette: Cotton Knits - Colors: #F3ECDA, #C4AC95, #94553D, #FFCBA4'
# 'Palette: Bamboo Beach - Colors: #FBF6F3, #FEB06A, #36D6E7, #5D6C89'
# 'Palette: Handpainted Sky - Colors: #5D59AF, #A072BE, #BE81B6, #E390C8'
# 'Palette: Milky Stream - Colors: #988780, #FFFFFF, #13292A, #E7DED9'
# 'Palette: Vintage Pastels - Colors: #FEEFDE, #DAE3E6, #DFDACD, #6E6D6E'
# 'Palette: Floaty Pool Fun - Colors: #F9B8B1, #F84791, #57DBD8, #25388E'
# 'Palette: Bare Beauty - Colors: #1F3541, #5289B5, #AFD8F2, #EDF2F3'
# 'Palette: Beautiful Abstraction - Colors: #0000FF, #4B7BF5, #79A9F5, #C2E2F5'
# 'Palette: Fur Strands - Colors: #FBC0C0, #FB6C90, #FB8DA0, #FB5490'
# 'Palette: Zesty Macaroons - Colors: #C5E5A5, #98B66E, #F9D876, #FBE39D'
# 'Palette: Ocean Threads - Colors: #2B4560, #E1E7E0, #6AA4B0, #2F6D80'
# 'Palette: Stairs and Mirrors - Colors: #FFFFF5, #F9F9FB, #FDF4E3, #B59F84'
# 'Palette: Sweet Frost Lips - Colors: #FBE7E0, #F9E4D0, #ECC0B0, #9C3940'
# 'Palette: Macaron de Paris - Colors: #B7A1A6, #C1C2AD, #EFD593, #EDC1BB'
# 'Palette: Tent Light Reflection - Colors: #A1AFA0, #F7EDD0, #970C10, #947360'
# 'Palette: Lemon Water - Colors: #8AE2E0, #F6C324, #3AA3A0, #F7D330'
# 'Palette: Salmon for Brunch - Colors: #F6A970, #F0DAC0, #EE7840, #5C5F30'
# 'Palette: Candy-frosted Doughnuts - Colors: #94DFE6, #EBDCC7, #B5EECB, #FCB9B5'
# 'Palette: Beach Bound - Colors: #FBE5C0, #F88379, #D0E6F0, #4C5D70'
# 'Palette: The Best Summer - Colors: #F8E5E6, #AAF1F5, #51B9CD, #3A5673'
# 'Palette: Ivy Swipe - Colors: #5E376D, #BD97CB, #F3EAC0, #747080'
# 'Palette: Inner Glow - Colors: #FBB80F, #FBEE0F, #C598AF, #7F4AA4'
# 'Palette: Deep Merlot - Colors: #F3E3E2, #74112F, #0C0C1E, #1B2E3C'
# 'Palette: Athleisure Style - Colors: #07DAC0, #171810, #D6DFE0, #CE2380'
# 'Palette: Peaceful Cottage Path - Colors: #E3E8F0, #82807F, #414754, #E5D7BE'
# 'Palette: Neon Pop - Colors: #F9F940, #F50CA0, #43DDE2, #EAC5B0'
# 'Palette: Style and Grace - Colors: #000000, #F41F4E, #FBFBFB, #FFC2C7'
# 'Palette: Thirst Quencher - Colors: #FEDE00, #B4F8C8, #6AB8EE, #A8D9F8'
# 'Palette: Cherry Blossom Dance - Colors: #BA8D80, #F0D9D0, #DFA8A3, #E2B080'
# 'Palette: Space for Everything - Colors: #EAEAEA, #BC9476, #ACBAAD, #C7A19B'
# 'Palette: Classic Travel - Colors: #AC8E60, #E9DAC4, #749EB2, #BD8E83'
# 'Palette: Burst of Sunshine - Colors: #F86F15, #FAC218, #DEB3AD, #F51663'
# 'Palette: Secret Romance - Colors: #EBE7D0, #D3A550, #121110, #D01110'
# 'Palette: Marshmallows in Tea - Colors: #C5E3F2, #A8CEE9, #EED6D3, #E29CB4'
# 'Palette: Cotton Dandelions - Colors: #013A20, #D4D6CF, #536F16, #3F4122'
# 'Palette: Garden Blur - Colors: #4C3D40, #BDB5C0, #C8B4D0, #F6EEF0'
# 'Palette: Fancy Cycle - Colors: #9A76A5, #B19FF9, #C89DD8, #E6DED3'
# 'Palette: #E6DED3 - Colors: #151B25, #034687, #DBE8E1, #E10032'
# 'Palette: A Colorful Summer - Colors: #FED43F, #2BB8B3, #E151AF, #BED7D8'
# 'Palette: Fondant Art - Colors: #51A7AD, #F1EDE3, #F7A7BF, #DCD2D8'
# 'Palette: Strong and Curved - Colors: #006884, #053D57, #F2F1EF, #97BCC7'
# 'Palette: Autumn Crush - Colors: #E1A140, #532200, #EFCFA0, #914110'
# 'Palette: Soft as Feathers - Colors: #E1ECF0, #54A2D2, #A9CEE8, #003A64'
# 'Palette: Hot Concrete - Colors: #47484A, #D49796, #DCAE96, #DBCAC0'
# 'Palette: Succulent Garden - Colors: #00E091, #00735C, #C1D9B7, #E5A298'
# 'Palette: Denim Delight - Colors: #B0D2DA, #CAB29F, #7DA1BF, #2F4A60'
# 'Palette: A Royal Bouquet - Colors: #420264, #5C038C, #1B1734, #896FBC'
# 'Palette: Cutout Paper Heart - Colors: #FF6584, #ABE8E6, #F0D7D9, #41B5AF'
# 'Palette: Coffee and Macarons - Colors: #79808A, #F1E6C8, #DCDCD0, #D3BAB1'
# 'Palette: Nineties Grunge - Colors: #00478F, #FF5D00, #2A231F, #D8E1E7'
# 'Palette: Country Skyline - Colors: #1966B0, #73D9F0, #F7B301, #EB773E'
# 'Palette: Sea Breeze - Colors: #57DDF3, #14C2DD, #A1F7A1, #C7F954'
# 'Palette: Sun-kissed Orchids - Colors: #27231F, #DE0001, #C8651B, #FEDA15'
# 'Palette: Seastorm Gloom - Colors: #333F63, #715C8C, #D7D4DD, #838BC2'
# 'Palette: Desert Blush - Colors: #F1ECE4, #CB7666, #A93D49, #EAB996'
# 'Palette: Surf's Up - Colors: #D3F4FB, #9DE3F6, #59D7EE, #53DFD1'
# 'Palette: Peacock Wings - Colors: #1C9B8E, #0F1E64, #53DFD1, #50655B'
# 'Palette: Ube Delight - Colors: #6E3562, #DFB160, #34586E, #D18D96'
# 'Palette: Pomegranate on Print - Colors: #07040A, #AB0552, #B175FF, #EFEBE2'
# 'Palette: Sun-kissed Rock - Colors: #FFE0AE, #F5631A, #A2ABCE, #FFA303'
# 'Palette: Daywear Eyeshadow - Colors: #F9F1F0, #DEB3AD, #A0877D, #25232B'
# 'Palette: Door of Fortune - Colors: #92794F, #DDCAB2, #C3B090, #F1ECE4'
# 'Palette: Buddhist Monk - Colors: #FBDD00, #E9A200, #B32800, #7F0000'
# 'Palette: Berry Jar - Colors: #C8F4F9, #7FE5F0, #513B41, #F83839'
# 'Palette: Bird of Prey - Colors: #FFDB15, #020301, #B5A197, #F3F5F9'
# 'Palette: Midnight Moon - Colors: #B1D4E0, #AFC1D0, #1C3F60, #0B1320'
# 'Palette: Cherry Blossom Swirl - Colors: #391306, #F1CED4, #710019, #F9CCD3'
# 'Palette: Lift Me Up - Colors: #ABEA7C, #F2E34C, #B2D7DA, #E151AF'
# 'Palette: Stepping Stones - Colors: #E4E5E8, #53565A, #4D0011, #4B443C'
# 'Palette: Deep Introspection - Colors: #6C6A61, #EDE4E3, #6C6A61, #C0C0C0'
# 'Palette: Forever Begins - Colors: #3B707D, #FFB85D, #FF5412, #030A04'
# 'Palette: Bonfire Glow - Colors: #970C10, #BFCAD0, #474440, #738580'
# 'Palette: Berry Tart Pie - Colors: #F4F2EB, #E4021B, #FFDB15, #3F5E98'
# 'Palette: Lucky Lime - Colors: #8FA01F, #1D741B, #8BCD50, #DED93E'
# 'Palette: Peach Party - Colors: #190204, #FF8976, #CB4E47, #FFCBA4'
# 'Palette: One Cool Ride - Colors: #16796F, #ADC9C5, #6CB0A8, #10564F'
# 'Palette: Teenage Pop - Colors: #71E7E0, #FF8BDA, #43A9DD, #F12E90'
# 'Palette: Lucid Lemonade - Colors: #00E2D3, #37A6A0, #90CDD0, #FFFEA8'
# 'Palette: Melon and Mint - Colors: #93E9BE, #F4B18C, #EBEEF1, #3B9778'
# 'Palette: Tasting Rainbows - Colors: #01DEE6, #FF66E9, #FF5412, #FBF608'
# 'Palette: Perfect Tan - Colors: #F2D6C0, #E5B990, #D79B70, #FDDBD8'
# 'Palette: Pleated Drapes - Colors: #00EAD9, #00C4B0, #138B83, #345351'
# 'Palette: California Citrus - Colors: #BDF0D6, #FFD294, #F7EBDB, #F3A089'
# 'Palette: Glow in the Dark - Colors: #A2C4E0, #F7CB2D, #52688F, #82A4E3'
# 'Palette: Bakery Bouquet - Colors: #EDD0C0, #C8626D, #B3C0AE, #BC8880'
# 'Palette: Citrus Slices - Colors: #016367, #9E3A14, #E66912, #0B1C48'
# 'Palette: Dark Metal - Colors: #0B0909, #44444C, #8C8C8C, #D6D6D6'
# 'Palette: Yarn Fuzz - Colors: #D95980, #63AAC0, #F99B45, #284E60'
# 'Palette: Grey Horizon - Colors: #F2F1F0, #C0C9CC, #A39D92, #636059'
# 'Palette: Pastel Heroine - Colors: #F09CA2, #B2C4CB, #999DA0, #F3F3E7'
# 'Palette: Waiting on Wind - Colors: #F0F7E0, #D3BBDD, #BC96CA, #95BA61'
# 'Palette: Picked Pineapple - Colors: #D9C1BB, #9AB19A, #52584D, #090A0E'
# 'Palette: To The Sky - Colors: #F7D4E0, #FD7AC0, #7AD7F0, #44C8E0'
# 'Palette: Reap and Sow - Colors: #E6B794, #B8DDD6, #E0EBE5, #AD9787'
# 'Palette: Young Navigator - Colors: #0B1C48, #ECD5BB, #FFFFFF, #710117'
# 'Palette: Bottle of Milk - Colors: #F4F7F0, #BFD2D0, #368980, #62CCC0'
# 'Palette: Pop of Balloons - Colors: #F0E5D0, #EECAC9, #FA3980, #F90067'
# 'Palette: Fruit Punch - Colors: #928D89, #FF8882, #FFA384, #E4E69B'
# 'Palette: Vintage Village - Colors: #7C9CAB, #E8CBB1, #FEECC3, #333A44'
# 'Palette: Touch of Rose - Colors: #FAA590, #B43930, #FBE5E0, #F28A80'
# 'Palette: Summer Color Pops - Colors: #F1E488, #01B9CC, #F3B9DF, #D3E9E7'
# 'Palette: Sunset Sightings - Colors: #F9E9D0, #DB8780, #A30052, #26161F'
# 'Palette: Fluorescent Fruit - Colors: #FFCE13, #88070B, #F65156, #009292'
# 'Palette: Fall Foliage Trip - Colors: #DC7726, #DDC077, #57896A, #4A545D'
# 'Palette: Rustic Project - Colors: #745D20, #CEA660, #F3EDE0, #6B7A40'
# 'Palette: Purple Floral Sunset - Colors: #A16AE8, #B19FF9, #0E3506, #FEA303'
# 'Palette: Blossom of Porcelain - Colors: #00E0D4, #EAEFF2, #FF4500, #EAEFF2'
# 'Palette: Peach Kiss - Colors: #FACB80, #FBD8B0, #F69770, #B52B40'
# 'Palette: Calming Serenity - Colors: #DCDBD8, #D1A58A, #5C97B8, #183A53'
# 'Palette: Petal Crush - Colors: #BFD7ED, #60A3D9, #0074B7, #003B73'
# 'Palette: Early Departure - Colors: #9CA0A1, #D7D4CC, #A7C0BE, #4D6772'
# 'Palette: Daily Cafe Ritual - Colors: #523A28, #228280, #BF6336, #EDF1F2'
# 'Palette: Glass of Freshness - Colors: #89BE63, #AFCCA9, #CFEDEE, #ECF9F2'
# 'Palette: Easter Cookie Basket - Colors: #5E376D, #F7E951, #D4BBDD, #F6E6E8'
# 'Palette: Makeshift Slumber - Colors: #050606, #FDFDFD, #D8D7D5, #ADB3BC'
# 'Palette: Seafoam Shimmer - Colors: #15998E, #45B08C, #48BCD1, #C0DCEC'
# 'Palette: Natural Collection - Colors: #1E1514, #FFFFFF, #ECD5BB, #013A20'
# 'Palette: Jewel-toned Sea - Colors: #FCA7A5, #5A3E79, #130329, #A76286'
# 'Palette: At the Brim - Colors: #A5CFE3, #00221C, #028476, #E7F6FC'
# 'Palette: Morning Duck Eggs - Colors: #F2E4CF, #D09064, #A96036, #DBC4AF'
# 'Palette: Summit Glow - Colors: #FBB574, #E88D72, #543855, #FF8882'
# 'Palette: Sandy Beach Path - Colors: #D6DDE0, #446FA0, #223C60, #51555B'
# 'Palette: Easter Soft - Colors: #D1A179, #F1E6D4, #C1C2AD, #CBE1DF'
# 'Palette: Vintage Camera - Colors: #715B5B, #A47C7A, #D6C5C4, #0F1110'
# 'Palette: San Francisco Fog - Colors: #4C5355, #C44B4F, #607D86, #CBCDCB'
# 'Palette: Pop Princess - Colors: #9FD9D0, #F7C9C0, #F34C50, #3AA7A0'
# 'Palette: Majestic Mountain - Colors: #1B2A37, #DCC5C3, #D6E1EB, #ADC4D7'
# 'Palette: Flaming Flower - Colors: #FFE0AE, #FF4500, #6C8255, #FFA303'
# 'Palette: Easter Quirks - Colors: #FCD699, #DDC9D8, #F6C8CC, #F09CA2'
# 'Palette: Muted Succulents - Colors: #A9BCB0, #E88670, #384960, #4C7D60'
# 'Palette: Swiftness of Water - Colors: #CCE0D2, #61C2A2, #2C8395, #1D617A'
# 'Palette: Market Tourist - Colors: #ADD3D0, #970C10, #153250, #FEFCFF'
# 'Palette: Natural Timbers Kitchen Baking - Colors: #F0D8B8, #634F40, #F3F0E9, #E6B794'
# 'Palette: Flash and Rave - Colors: #F248B6, #14527C, #080B39, #69124A'
# 'Palette: Ballet Dreams - Colors: #EEE7E0, #725450, #C6AD90, #F7CAC9'
# 'Palette: Easter Egg Hunt - Colors: #ECF87F, #E4A58F, #97D49B, #A6E2DC'
# 'Palette: Plaid Pair - Colors: #314E70, #35D5D0, #EDAEC0, #EBEEE0'
# 'Palette: Nutty Strawberry Popsicle - Colors: #F36870, #E8DAC0, #FFB7B0, #A9C5D0'
# 'Palette: Candy Color Pop - Colors: #A6DFEB, #FC979D, #F8CD4F, #FB4A9B'
# 'Palette: Morning Dew - Colors: #31ED31, #10BC10, #11A7BB, #2AB67B'
# 'Palette: Cloud City - Colors: #3A6A59, #A7A88A, #D6C18A, #B9C8BC'
# 'Palette: Brilliant Bokeh - Colors: #FFB001, #44EE77, #019992, #FB475E'
# 'Palette: Halved Lemons - Colors: #F7DD80, #8AE2E0, #F7D330, #3AA3A0'
# 'Palette: Artisan Dream - Colors: #0B1F65, #E8E3CC, #D7A449, #DB3F29'
# 'Palette: Pastel Appeal - Colors: #F7D8D9, #A1DBE5, #FFD8C0, #00B7AF'
# 'Palette: Ocean Depth - Colors: #067593, #055772, #09A9C8, #001F3D'
# 'Palette: Blue Headlights - Colors: #061E47, #68A4F1, #2B6AD0, #1F4591'
# 'Palette: Bohemian Brick - Colors: #F0EDE0, #433F30, #970C10, #918E80'
# 'Palette: Sip of Orange - Colors: #B4F8C8, #FBC858, #FF8210, #565819'
# 'Palette: Bittersweet Blues - Colors: #D3D2C7, #5B89AE, #ADC4D7, #CB8E66'
# 'Palette: Curving into Water - Colors: #08392B, #578E87, #F7E2C7, #29660C'
# 'Palette: Benches in Fall - Colors: #F5631A, #FEEBA0, #D41E00, #481D01'
# 'Palette: Pick Up Sticks - Colors: #A9B7C2, #D0B49F, #4A6F89, #EECE88'
# 'Palette: Center of Life - Colors: #F8A8C5, #FBD160, #EB63A0, #E44650'
# 'Palette: Drink Life In - Colors: #E2D9CA, #4A94A8, #2B293C, #6A4973'
# 'Palette: High and Bright - Colors: #FBBC54, #F8DCB0, #FC5E70, #F2B190'
# 'Palette: Secret Spring - Colors: #8C9B88, #F5E8DA, #735E93, #EFF1EF'
# 'Palette: Pop the Bubbles - Colors: #04F9F2, #0091E7, #005BEA, #0000FF'
# 'Palette: Shades of Contrast - Colors: #B5F2EE, #FF7930, #00E0EA, #F9F1E0'
# 'Palette: Alluring Shadows - Colors: #3D393B, #7E1E80, #9505E3, #B637FB'
# 'Palette: Ribbon Around Rosettes - Colors: #DEB3AD, #EB7C8F, #DC5D85, #DFD1C5'
# 'Palette: Monochromatic Party - Colors: #040000, #F6C7A5, #F2D0C1, #F7F8F8'
# 'Palette: Sweet Lilac Cake - Colors: #A58CB3, #A16AE8, #EAE7FA, #D9A1A0'
# 'Palette: Soft Pastel Evening - Colors: #D0DEE5, #E89394, #F6F1E7, #988E92'
# 'Palette: Pastel Popsicles - Colors: #FCDCA9, #ECC4B3, #B8D0DD, #669DBA'
# 'Palette: Secret Keeper - Colors: #FC4DB0, #F9E830, #221530, #F52870'
# 'Palette: Pensive Mood - Colors: #E5E8E8, #8D9797, #4E545C, #000401'
# 'Palette: Breakfast Coffee Spread - Colors: #6B1B00, #AE8B70, #F9FEFB, #56382D'
# 'Palette: Still Growing - Colors: #719F1E, #4A7212, #D5CE58, #104210'
# 'Palette: Survived Tide - Colors: #9DBED1, #14829F, #D8E3EC, #004F76'
# 'Palette: Brights and Specs - Colors: #21C5C4, #F9E950, #FF94B2, #C14F60'
# 'Palette: Frozen Berries - Colors: #B0B7C0, #171710, #707370, #595E60'
# 'Palette: February Sky - Colors: #F6D4D2, #EDD1FA, #9FA8EB, #4120A9'
# 'Palette: Unicorn Trail - Colors: #E6694C, #FF8D80, #F9C8B0, #68E7E0'
# 'Palette: Vanilla-frosted Cupcake - Colors: #E4F4F3, #A1DBF1, #71D5E4, #00B6BC'
# 'Palette: Mod Interiors - Colors: #73436D, #E5E6E9, #B67C9A, #1F252F'
# 'Palette: Path at Dusk - Colors: #A2C4E0, #F7CB2D, #0D659D, #1390E0'
# 'Palette: Quiet Beauty - Colors: #F1BECA, #B95C50, #CD7E7F, #F3E4E2'
# 'Palette: Soft Punk - Colors: #FBDCC0, #DDAFB0, #8F6980, #1C2520'
# 'Palette: Lemon Fresh - Colors: #FFCE66, #F9AB40, #A9E5D5, #44455B'
# 'Palette: Sliver of Silver - Colors: #E5DACE, #BCBEC0, #5C5350, #3C3630'
# 'Palette: Lavender Horizon - Colors: #603F8B, #B9A7BB, #323B36, #616C59'
# 'Palette: Candy Corn Craze - Colors: #FDD264, #FFC680, #F56B39, #670305'
# 'Palette: New Beginnings - Colors: #EDE7D0, #FDCD93, #034F39, #549369'
# 'Palette: Earth Hands - Colors: #4F3750, #CB9870, #8D8960, #AAA1A0'
# 'Palette: Summer Flair - Colors: #2FF3E0, #FF8000, #E09D60, #1F3960'
# 'Palette: Antique Rose - Colors: #9F90CF, #0461B1, #B1365B, #E9D8E1'
# 'Palette: Coffee and Berries - Colors: #6B3A2C, #C9B1C6, #3B0918, #C9B1C6'
# 'Palette: Bubble Pop Frosting - Colors: #E78484, #FCA4A2, #47D3CE, #C8F4F9'
# 'Palette: Crystal Feline - Colors: #63747A, #C0C2C9, #123175, #5298C1'
# 'Palette: Cheerful Sands - Colors: #29B3FF, #81EAFF, #FBC00E, #FFD774'
# 'Palette: Mountain Lake - Colors: #29660C, #F7E2C7, #578E87, #1C4508'
# 'Palette: Assorted Sweets - Colors: #F8D7A8, #EF9771, #DDDDA4, #7B583D'
# 'Palette: Turquoise Sky - Colors: #C8F4F9, #1592B4, #E0A030, #A06204'
# 'Palette: Mountains at Dusk - Colors: #E08955, #0048A4, #E35A01, #689AB8'
# 'Palette: Sweet Orchid - Colors: #A3C14A, #6D8343, #D103D1, #6E3562'
# 'Palette: Hawaiian Blossom - Colors: #FF0F39, #FEDA15, #7E9DC2, #F8F8F8'
# 'Palette: Tiny Ripples - Colors: #10564F, #21B6A8, #30D9C8, #75E6DA'
# 'Palette: Sting has Sprung - Colors: #A92420, #D1913E, #0E3160, #135390'
# 'Palette: Starting Blossom - Colors: #F2DAD0, #ECB4B9, #EA85C7, #899A89'
# 'Palette: Egg Carton - Colors: #D8CEE6, #72435C, #B4F8C8, #424651'
# 'Palette: Sliver of Nature - Colors: #627E8B, #D2CCCC, #EAEDF0, #184B29'
# 'Palette: Eighties Skater Girl - Colors: #E9679B, #F8CD4F, #B9A3D1, #6EE0E0'
# 'Palette: Scented Soap - Colors: #FFFFFF, #E9D8E1, #E5CEF6, #B655C8'
# 'Palette: Calm Perspective - Colors: #FCF8F6, #00BBD1, #00E0EA, #96A1A8'
# 'Palette: Chocolate Pastries - Colors: #F0E7E4, #131919, #634F40, #B49A87'
# 'Palette: Basking the Ambience - Colors: #FAFBF4, #00A0F3, #0000FF, #000066'
# 'Palette: Fall Fashion - Colors: #F3CC3C, #D19A30, #7D3F20, #000000'
# 'Palette: Sun Drenched Blooms - Colors: #FBDC6A, #B12B24, #760504, #090A0E'
# 'Palette: Winter Sport - Colors: #ECF1F2, #7F7F7F, #F4D800, #050707'
# 'Palette: Mermaid Fin - Colors: #65DFF6, #00478F, #1A83CC, #CBEBF5'
# 'Palette: Terracotta Workshop - Colors: #BBC0B6, #D58469, #F0EDE4, #435861'
# 'Palette: Northern Lights 3 - Colors: #088280, #063340, #008000, #04D010'
# 'Palette: Blossom Rows - Colors: #3C4C70, #DCA1B0, #EDEEF1, #9168A0'
# 'Palette: Lead the Way - Colors: #2B6670, #637E90, #77A7B0, #E5F2F0'
# 'Palette: Winter Warmth - Colors: #970C10, #EFF4F0, #384640, #244C60'
# 'Palette: Green Tracks - Colors: #1E3148, #9E6F6D, #E6D7D5, #43B14B'
# 'Palette: Ode to Sea - Colors: #0074DD, #9BCCFD, #36D6E7, #81599F'
# 'Palette: Autumn's Here - Colors: #F76201, #FEEBA0, #D41E00, #672901'
# 'Palette: Spring Contrast - Colors: #104210, #6A8820, #D3C02F, #F2E437'
# 'Palette: October Skies - Colors: #9271C2, #2D1674, #FFF2FF, #703ACF'
# 'Palette: Quill and Carton - Colors: #E3E6E0, #252930, #C0B3A0, #6B8490'
# 'Palette: Lost in Leaves - Colors: #2B4310, #4E7130, #C9B590, #95B250'
# 'Palette: Hand in Hand - Colors: #B83330, #CBD7D0, #F3EDE0, #D5B690'
# 'Palette: Shake Your Feathers - Colors: #043BB1, #1E8AD3, #10BC10, #1D3537'
# 'Palette: Bubblegum Popstar - Colors: #FDF2E7, #FEE900, #04D3BC, #FECCC8'
# 'Palette: Sweet Succulents - Colors: #D0B49F, #C0D39A, #4F5F2C, #2A291C'
# 'Palette: Xylem Drops - Colors: #016236, #02894B, #06040A, #BED3AB'
# 'Palette: Nature Tunes - Colors: #E9DAC4, #39221F, #EF813E, #5E6826'
# 'Palette: Perfect Contrasts - Colors: #0000A3, #004197, #7F3E71, #DF265E'
# 'Palette: Plum Tulips - Colors: #3F6D3C, #F7BBDB, #FF0BAC, #7B163E'
# 'Palette: Hot Air Weekend - Colors: #2B18A3, #F353D5, #E9D8E1, #88C9FA'
# 'Palette: Sweater Weather - Colors: #3B2244, #105160, #2D7670, #CD966B'
# 'Palette: Freeze this Moment - Colors: #003366, #71B1C5, #CBE6EF, #F0F2F3'
# 'Palette: Plum Kisses - Colors: #7A0051, #D3B1C2, #240831, #E44B7D'
# 'Palette: School of Fish - Colors: #CDD3D0, #87B1B0, #386E90, #344A70'
# 'Palette: Gentle Petals - Colors: #FDF2ED, #F7C9B6, #F1A17E, #A53E12'
# 'Palette: Warm and Melted - Colors: #E36920, #EFA710, #E8D4C0, #DCAD90'
# 'Palette: Meeting the Sun - Colors: #F09360, #F62280, #FB8FC0, #F9BF50'
# 'Palette: Electric Neon Plate - Colors: #738A76, #65FC6A, #FF0BAC, #E4F995'
# 'Palette: Crimson and Blues - Colors: #FF2768, #A3A3B7, #1B4A56, #F2EEF7'
# 'Palette: Caught by Summer - Colors: #3B2244, #A06AB4, #E845AE, #EBA408'
# 'Palette: Hint of Rose - Colors: #8F4553, #F4F3F1, #E6E5E3, #E2ACB9'
# 'Palette: Party Time Sprinkles - Colors: #64D5DD, #57A5B8, #F68181, #A94A5F'
# 'Palette: Sky Reflections - Colors: #BAD3E4, #1E77BD, #10564F, #04345C'
# 'Palette: Snowed In - Colors: #ECF1F2, #53565A, #F4D800, #050707'
# 'Palette: Evening Calm - Colors: #001F3D, #151983, #1863D6, #B6CBE1'
# 'Palette: Party for One - Colors: #FEFAE5, #D4C5B6, #C4CEC5, #6E726E'
# 'Palette: Neutral Seaside Wedding - Colors: #686A4E, #CFCDC2, #977557, #757573'
# 'Palette: Wear Your Confidence - Colors: #1B2E3C, #0C0C1E, #4D0011, #F3E3E2'
# 'Palette: Vandal Pigment - Colors: #256C70, #BF0D70, #F054B0, #E0E9D0'
# 'Palette: Classic Gentleman - Colors: #325980, #D4C2B0, #202E50, #777180'
# 'Palette: Attention to Details - Colors: #EEDEE0, #F87DB0, #EF5C90, #BC2D40'
# 'Palette: Citrus Treats - Colors: #787D12, #567C09, #BCC41C, #EBF094'
# 'Palette: Autumn Skyline - Colors: #DC7726, #ECC046, #F5F7ED, #42C0D2'
# 'Palette: Sunlit Day Out - Colors: #DDDBDB, #EEA5A6, #9E968E, #FBC99C'
# 'Palette: College Daze - Colors: #FFBF90, #F36870, #CED6CA, #FFF5D7'
# 'Palette: Pops of Blush - Colors: #EA3160, #142B70, #E99EB0, #4652A0'
# 'Palette: Memory Box - Colors: #6D3D38, #E9DAC4, #E0AC8E, #514843'
# 'Palette: Sweet Toppings - Colors: #13C3F7, #FF2768, #E9E9E7, #FFF387'
# 'Palette: Grained Memories - Colors: #040A18, #0B1C47, #F5F5E9, #873F49'
# 'Palette: Perfect Beach Vistas - Colors: #008FDE, #A4D8FB, #38CCED, #9571AB'
# 'Palette: Take a Break - Colors: #654E30, #527640, #212510, #1A3315'
# 'Palette: Fog Over Water - Colors: #23424A, #65A9A6, #ECECEB, #3B707D'
# 'Palette: Calming View - Colors: #D5D5C0, #4DDDE0, #31CCE0, #1DB3C0'
# 'Palette: On Thick Ice - Colors: #E3EFF9, #AACDE5, #6CC4DC, #3F92B7'
# 'Palette: Coffee Craving - Colors: #DFD6D1, #1F232C, #FFFFFF, #83746E'
# 'Palette: Sky Balloons - Colors: #1848A0, #47D8E0, #59CEE0, #2692D0'
# 'Palette: Pinch of Lime - Colors: #F8FFCA, #B6D084, #FFCB32, #2F7604'
# 'Palette: Carnation Petals - Colors: #F7CBCA, #EC6964, #F18370, #721816'
# 'Palette: Floral Dazzle - Colors: #C9D9F0, #8155BA, #FEC437, #FE5BD6'
# 'Palette: Fall Fire - Colors: #F1D26C, #2B1200, #CF5C00, #8D1E00'
# 'Palette: Waterside Retro - Colors: #130170, #CDF4DC, #01949A, #CD0046'
# 'Palette: Painting with Light - Colors: #000C20, #EF3340, #F1B420, #FFFAE0'
# 'Palette: Paper Cities - Colors: #201A1E, #D0B49F, #E4D4C8, #E2E6E7'
# 'Palette: Neon Bikini - Colors: #7268B0, #DC8CB0, #2DD220, #E721A0'
# 'Palette: Head-to-toe Flush - Colors: #F5D5E4, #E66579, #FCC0C5, #F7E7CE'
# 'Palette: Four-layered Cake - Colors: #BF8422, #361B28, #BC9C22, #B6CCD7'
# 'Palette: Dazzling Style - Colors: #E928A0, #271140, #3CBED0, #E6D350'
# 'Palette: Squishy Toes - Colors: #E8C6AE, #D4C7AF, #BDB8B6, #807672'
# 'Palette: Winter Overture - Colors: #00264C, #36454F, #A3ABB0, #D4D0D0'
# 'Palette: Sweet Crowning Glory - Colors: #222C45, #9EBFCF, #8E7B96, #EED6D3'
# 'Palette: Wild Cherry Blossom - Colors: #9782AD, #F05B06, #F3B9DF, #9D1B6F'
# 'Palette: Oven-baked Chocolate Chip - Colors: #C3A57C, #C1937D, #C1B199, #DED8CD'
# 'Palette: Summer Cocktails - Colors: #65D4EE, #9DE89C, #FAC12F, #CFE9EF'
# 'Palette: Close of Day - Colors: #203946, #778D99, #C6AE96, #FF9936'
# 'Palette: The Ripe Time - Colors: #EBE99E, #8BCA67, #F9D976, #055816'
# 'Palette: Creative Cupcakes - Colors: #FD7924, #57A5B8, #E21B32, #ECEF5B'
# 'Palette: Tropical Sweetheart - Colors: #DCA7A0, #165C40, #E17A82, #8CC7C0'
# 'Palette: Bright and Bold - Colors: #5BDCE1, #E73BA5, #F4975B, #F9D8CE'
# 'Palette: Finally Opened Up - Colors: #590C69, #4A0D4A, #D19FC6, #398FC7'
# 'Palette: Chill Dawn - Colors: #5B5C50, #1B1E1E, #C2AD90, #E4DCC0'
# 'Palette: Neon Glam Madam - Colors: #4C3260, #E43480, #EAD4C0, #F43AB0'
# 'Palette: Melted Chocolate - Colors: #252827, #FFFEE6, #291211, #F8CF2C'
# 'Palette: Sliced Citrus - Colors: #E35A01, #4C7C71, #2E4769, #1F262E'
# 'Palette: Cheer Me Up - Colors: #4E514E, #988C80, #E0A39F, #F9EBE1'
# 'Palette: Candy Skyline - Colors: #DCF2F0, #FFE65B, #FAD7F3, #66B8C9'
# 'Palette: Hot Chili Peppers - Colors: #686361, #E32227, #1A7CFA, #0070E0'
# 'Palette: Before Nightfall - Colors: #8EB7CE, #54627B, #A2BEEF, #FBB2A3'
# 'Palette: Autumn Squash - Colors: #B14100, #E39E30, #8A5920, #8FAE70'
# 'Palette: Empty Auditorium Seats - Colors: #1E1200, #8B8060, #FDFFF0, #970C10'
# 'Palette: Ice Cold Rosé - Colors: #EFEAE0, #E98FC0, #9E8F90, #CD6090'
# 'Palette: Warm Shadows - Colors: #603840, #BD8990, #9F94A0, #B7D0E0'
# 'Palette: Morning Dew - Colors: #028476, #015D53, #030303, #6ECB5A'
# 'Palette: Communing with Nature - Colors: #E4D7CF, #8A3240, #617969, #98705D'
# 'Palette: Birthday Cake - Colors: #FBDFA0, #FFC2C7, #5DD9FB, #BBD5D2'
# 'Palette: Feminine Bow Tie - Colors: #874A5B, #232425, #E3CDBC, #AFB2AE'
# 'Palette: Nightfall Ambiance - Colors: #003D7A, #051537, #04247C, #0458AB'
# 'Palette: Wealth of Nuts - Colors: #A4AA83, #D8DDB8, #4C411A, #F3EED9'
# 'Palette: Pastel Vacation - Colors: #FDBFAF, #FCEE96, #7EB6D7, #4D5264'
# 'Palette: Lit by Candles - Colors: #474241, #CDA67A, #A7A88A, #D0CCB9'
# 'Palette: Mulberry Smoke - Colors: #2B192E, #F5E8DA, #50006C, #CE8CA5'
# 'Palette: Cuddle Weather - Colors: #383940, #A98AB0, #F1F1F0, #ADA9AD'
# 'Palette: Tulip Meadow - Colors: #FAD02C, #E12A2A, #469A49, #192A29'
# 'Palette: Rosy Lavender - Colors: #B80454, #1D190A, #B175FF, #DCBCD0'
# 'Palette: Sun and Sand - Colors: #FFFFFF, #F7E7CE, #A2A3AA, #AA9C92'
# 'Palette: Bright Northern Lights - Colors: #117660, #09323B, #04B16F, #14E114'
# 'Palette: Summer Soft - Colors: #B46490, #E3D9E0, #F1ECD0, #634F50'
# 'Palette: Midnight Swim - Colors: #08153A, #0B1F65, #2535D9, #C08D2C'
# 'Palette: Dessert Deluxe - Colors: #EDE5E1, #95675B, #C6A590, #D4AC74'
# 'Palette: Retro Road Trip - Colors: #7A403E, #9F2B00, #F89700, #D8CD9D'
# 'Palette: Dusty Rose - Colors: #592F2D, #402220, #B5605C, #EEB4A4'
# 'Palette: Morning Ritual - Colors: #A9BA88, #D9C6BF, #F6F0E7, #6D6F73'
# 'Palette: Vanilla Amandine - Colors: #7A3E26, #CF6856, #F7E7CE, #FFFFFF'
# 'Palette: New Wave - Colors: #E80000, #1E73BE, #C850B0, #660A60'
# 'Palette: Pure Olive Oil - Colors: #DDB040, #D1B780, #E3E5E0, #464239'
# 'Palette: Captivating Cupcake - Colors: #E6BDCC, #ECEADB, #A3768B, #DEBAD6'
# 'Palette: Springtime Sports - Colors: #E5E1D9, #DAA7A2, #A7A88A, #37391E'
# 'Palette: Evening Stroll - Colors: #A2C4E0, #F7CB2D, #071330, #122E76'
# 'Palette: Bunch of Blueberries - Colors: #192740, #4B6D90, #85AED0, #B8D1E0'
# 'Palette: Sugar Rosettes - Colors: #FFBBCA, #ECFDF1, #B4F8C8, #EFEDC6'
# 'Palette: Morning Breeze - Colors: #9DCED0, #A98AB0, #F0F1CF, #8EA350'
# 'Palette: Violet Ice Cream - Colors: #287686, #DFD1A9, #C79FA7, #603F8B'
# 'Palette: Concert Lights - Colors: #40B5F0, #2144C0, #142270, #030303'
# 'Palette: Desert Blooms - Colors: #343920, #F8F9F7, #71743A, #D5BA90'
# 'Palette: Deeper Waves - Colors: #00BFD6, #CADFD9, #8BD1E4, #00B5A2'
# 'Palette: Popping Colors - Colors: #07D2BE, #F24E70, #B4F8C8, #0F1300'
# 'Palette: Waiting Seagull - Colors: #74B2D0, #FFF593, #F36870, #FAFAF0'
# 'Palette: Splash Up Shore - Colors: #3E4B59, #87939E, #FD9096, #D6F7F8'
# 'Palette: Comfort Coffee Cup - Colors: #806460, #D4CBC0, #A1AEA0, #704F70'
# 'Palette: Carnival of Feathers - Colors: #E2B327, #4693B8, #0B1F65, #E1D9D1'
# 'Palette: Tinted Glass - Colors: #D6E2E8, #91C1D8, #0070AC, #003371'
# 'Palette: Juicy Slices - Colors: #FFDA77, #F1AFC0, #0696B0, #D83471'
# 'Palette: All Star Classic - Colors: #4B443C, #4D0011, #232425, #E4E5E8'
# 'Palette: Tropical Sunset Paradise - Colors: #F1B416, #E56A19, #000000, #900000'
# 'Palette: Sailor's Delight - Colors: #000000, #3A4968, #FF4500, #0087CA'
# 'Palette: Ocean Meets Sky - Colors: #98D7C2, #A1A3A5, #05ABC4, #0490AE'
# 'Palette: Shoot for the Stars - Colors: #DD819C, #3B1F52, #1E142B, #A05987'
# 'Palette: Curve of Water - Colors: #04425B, #BBCBBE, #16796F, #10564F'
# 'Palette: Succulent Garden - Colors: #04DC77, #016236, #B6D2A5, #D89384'
# 'Palette: Tidal Wave - Colors: #CFE0EA, #01949A, #578384, #016367'
# 'Palette: Lily Leap - Colors: #40C69F, #2E765E, #D62B83, #05234C'
# 'Palette: Relaxed Retro - Colors: #CCA78A, #EEEEEE, #DCB4B1, #BDF0D6'
# 'Palette: Candy Style - Colors: #5558D8, #D4BBDD, #FBD3DA, #8ADFE3'
# 'Palette: Breakfast Mocha - Colors: #F3E5C3, #D3A771, #CFC0AE, #694532'
# 'Palette: Fresh Succulent - Colors: #13292A, #91CABE, #499FA4, #B5DFD6'
# 'Palette: Rich Farm Picks - Colors: #9ABA12, #37520B, #DEE64C, #66930C'
# 'Palette: Pine View - Colors: #606462, #EDF0EE, #00735C, #00493A'
# 'Palette: Blush of Trees - Colors: #E5A298, #C1D9B7, #2C7721, #00E091'
# 'Palette: Buildings in Winter - Colors: #BED1DF, #546E81, #001F3D, #9CB9CC'
# 'Palette: Firey Cracked Earth - Colors: #499FA4, #A9582B, #BA9973, #EDDF9C'
# 'Palette: Lilac Shimmer - Colors: #3E004A, #ADE292, #4120A9, #7800A2'
# 'Palette: Marbled Blue Easter Eggs - Colors: #ADC8D2, #9F9C93, #54627B, #F4F4F6'
# 'Palette: Steadfast Stainless - Colors: #091235, #14202E, #2B4257, #88A9C3'
# 'Palette: Wheat in Wind - Colors: #C98169, #E0EBE5, #B8DDD6, #E6B794'
# 'Palette: Chocolate Mousse - Colors: #65463E, #B99A87, #C9BEB1, #EBEBE5'
# 'Palette: Very Berry - Colors: #9D5060, #E7DFE0, #376380, #2D1F30'
# 'Palette: Love and Macarons - Colors: #490E08, #F1A17E, #F7C9B6, #F7DC6F'
# 'Palette: Winter Musings - Colors: #676E7F, #0F0D12, #F9F6F0, #B6737C'
# 'Palette: Pastel Bike - Colors: #475250, #9589A9, #B5EECB, #F8A2A8'
# 'Palette: Much Needed Break - Colors: #42C3F7, #00A5E9, #003A6B, #E7EDEB'
# 'Palette: Papery Blossom - Colors: #CDCBAF, #5F6510, #723056, #B67C9A'
# 'Palette: Stretch of Sand - Colors: #5CCCCB, #F6F0E7, #1C799E, #908984'
# 'Palette: Jungle Vibe - Colors: #2B8E8E, #73B03A, #5CD85A, #278ED5'
# 'Palette: Surprising Images - Colors: #EED6D3, #69C9BC, #F7BCA5, #F7837C'
# 'Palette: Wrap Around Style - Colors: #0F7D80, #E2BAB0, #FF96B7, #5FD3C8'
# 'Palette: Endless Cubes - Colors: #34DED0, #94FAF0, #3AF7F0, #31D1D0'
# 'Palette: Fog and Waterfall - Colors: #756457, #3B3C38, #D5BBA9, #F1ECE4'
# 'Palette: San Francisco Mornings - Colors: #738580, #3E3E3E, #BFCAD0, #970C10'

# %% [markdown]
# # Initiating LLAMA3
# ---
# #### Reminder: Remember to run "ollama serve" in the terminal before running this script

# %% [markdown]
# ### Limitations

# %% [markdown]
# There are quite a number of limitations when using Ollama. One of them is that I am unable to set the temperature or the tone. Another is that it does not do well with looking up on the history of the chat. So I had to add reminders like only using the palettes provided, which sometimes does not always work. Probably have to look somewhere else to have more control.

# %% [markdown]
# ### Gathering Hex codes and recognized Colour Palettes

# %% [markdown]
# After testing, the LLM is able to recommend hex codes and colour palettes which is pretty handy, especially for colour palettes that are not in the dataframe. I will be using that to generate more custom colour palettes and add to the dataframe, so that the user has more variety to reccommend the clients.

# %%
#Test prompt
# I have a 4 year old daughter who loves the colour pink. Could you suggest colors that would be suitable for her?

# %%
def extract_hex_codes(text):
    # Regex pattern to match hex codes
    pattern = r'#[0-9A-Fa-f]{3}(?:[0-9A-Fa-f]{3})?\b'
    
    # Find all matches of the pattern in the text
    hex_codes = re.findall(pattern, text)
    
    return hex_codes

# %%
def match_palette_names(response, df):
    matched_names = []

    # Using regex to also include common conjunctions and prepositions like 'and', 'or', 'of', etc.
    potential_names = re.findall(r'\b[A-Z][a-z]+(?:\s(?:and|or|of)\s[A-Z][a-z]+)*', response)
    
    # Expand the search to include more potential matches by allowing the inclusion of multiple segments with conjunctions or prepositions
    extended_search = re.findall(r'\b[A-Z][a-z]+(?:\s(?:and|or|of)\s[A-Z][a-z]+|\s[A-Z][a-z]+)*', response)
    potential_names.extend(extended_search)
    
    # Check each potential name against the palette names in the DataFrame
    for name in set(potential_names):  # Use set to avoid duplicates from extended search
        if name in df['Name'].values:
            matched_names.append(name)
    
    return matched_names

# %% [markdown]
# ### Setting the prompt for the introduction and conditions for LLM to follow

# %%
introduction_input = "You are an interior designer in this app and are tasked to suggest colour palettes to suit their preferences based on their description. Set a professional tone when responding."

condition_input = "When suggesting colours, do include the hex codes in all of the response and have it as a seperate list. Do not suggest any products or furnitures. Only suggest colours and colour palettes."

# %% [markdown]
# ### Putting the introduction, condition and colour palettes reference list into the conversation history

# %%
# Initialize conversation history
conversation_history = [
    {'role': 'system', 'content': introduction_input},
    {'role': 'system', 'content': condition_input},
    {'role': 'system', 'content': color_palette_output}
]

# %% [markdown]
# ### Running LLAMA3

# %% [markdown]
# Only stops when user's input is empty

# %%
hex_codes_list = []
colour_palette_list = []

# %%
while True:
    user_input = input("You: ")

    if not user_input:
        break
    
    # Add the new user input to the conversation
    conversation_history.append({'role': 'system', 'content': condition_input})
    conversation_history.append({'role': 'system', 'content': color_palette_output})
    conversation_history.append({'role': 'user', 'content': user_input})
    
    # Generate response
    stream = ollama.chat(
        model='llama3',
        messages=conversation_history,
        stream=True
    )
    
    response = ""
    for chunk in stream:
        print(chunk['message']['content'], end='', flush=True)
        response += chunk['message']['content']

    
    # Add the response to the conversation history
    conversation_history.append({'role': 'system', 'content': response})

    #This will extract all hex codes the LLM generate
    codes = extract_hex_codes(response)
    for code in codes:
        if code not in hex_codes_list:
            hex_codes_list.append(code)
            

    #This will extract all colour palettes the LLM generate that matches with colour palettes in the Dataframe
    matched_names = match_palette_names(response, canva_palettes_df)
    if matched_names:
        for name in matched_names:
            if name not in colour_palette_list:
                colour_palette_list.append(name)
# Out:
# What a sweetie! I'd be happy to help you find some lovely color palettes for your little princess!
#
# Based on your request, I'll recommend some pink-inspired palettes from my list:
#
# 1. **Lilac Shimmer**: A soft and romantic palette featuring #3E004A (a light lilac), #ADE292 (a gentle yellow-green), #4120A9 (a deep berry pink), and #7800A2 (a rich plum). Perfect for a sweet 4-year-old!
# 2. **Candy Style**: A playful and whimsical palette with #5558D8 (a pastel blue-pink), #D4BBDD (a soft peach), #FBD3DA (a warm beige), and #8ADFE3 (a pale aqua). Your little one might enjoy these colors!
# 3. **Fresh Succulent**: A bright and cheerful palette featuring #13292A (a deep green), #91CABE (a vibrant pink), #499FA4 (a soft peach), and #B5DFD6 (a creamy white). This palette is perfect for a lively and energetic 4-year-old!
# 4. **Blush of Trees**: A gentle and soothing palette with #E5A298 (a light coral), #C1D9B7 (a pale green), #2C7721 (a deep brown), and #00E091 (a soft mint). This palette is ideal for a sweet and nature-loving little one!
#
# Feel free to pick the one that resonates with your daughter's personality, or mix-and-match colors from these palettes to create a unique combination that she'll love!

# %% [markdown]
# ### Prints list of Hex codes gathered from the replies from the LLM

# %%
print(hex_codes_list)
# Out:
# ['#3E004A', '#ADE292', '#4120A9', '#7800A2', '#5558D8', '#D4BBDD', '#FBD3DA', '#8ADFE3', '#13292A', '#91CABE', '#499FA4', '#B5DFD6', '#E5A298', '#C1D9B7', '#2C7721', '#00E091']

# %% [markdown]
# ### Prints list of recognized colour palettes gathered from the replies from the LLM

# %%
print(colour_palette_list)
# Out:
# ['Blush of Trees', 'Lilac Shimmer', 'Candy Style', 'Fresh Succulent']

# %% [markdown]
# ---

# %% [markdown]
# # Limitations

# %% [markdown]
# - Inability to accurately detect complex patterns or identify products with multiple colors.
# - Recommendation System is computationally expensive because of the amount of data is in the image per product.
# - There are no controls to set the tone/temperature.
# - Limitations exist in defining the context's scope and boundaries. Occasionally, the LLM might supplement its responses with additional information.
# - Catalogue dataset is not clean. When scraping, there are a lot of images that are not images of the product.

# %% [markdown]
# ---

# %% [markdown]
# # Recommendations

# %% [markdown]
# 1. More Resources for Data Collection and Cleaning:
#
#    - Expand the dataset by collecting more diverse examples of materials and products. Gathering images that showcase a variety of material types and products with complex patterns and multi-coloured designs to improve the system’s recognition and classification capabilities.
#    - Replace the incorrect images of the products to the proper images of the product to allow the recommendation system to recommend.
#
# 2. Implement Advanced Image Recognition Technologies:
#    Integrate more sophisticated image processing algorithms that can handle complex patterns and multi-color detection more effectively. Consider using deep learning models trained specifically for material recognition and pattern analysis.
#
# 3. Explore Retrieval-Augmented Generation (RAG) for LLM:
#    Investigate the potential of RAG to enhance the LLM's performance. By integrating a retrieval mechanism, the LLM can access a broader knowledge base during generation, allowing for more contextually relevant and updated responses. This approach would be particularly beneficial in cases where dynamic data and evolving trends influence design decisions.

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions

# %% [markdown]
# By automating the task of matching and suggesting interior design products, the system not only saves time but also introduces a level of precision in aligning with client preferences that manual processes cannot easily achieve.
#
# However, recognizing the limitations in pattern recognition and material classification, it is clear that continued improvements and updates are necessary to maintain and enhance the system's effectiveness. By implementing the recommended actions, we can ensure that the system evolves in line with advancements in technology and changes in design trends, thereby providing enduring value to interior designers and their clients.
#
# Through these efforts, we will support interior designers in overcoming the initial difficulties and efficiently navigating client preferences, ultimately leading to more inspired and harmonious design solutions.
